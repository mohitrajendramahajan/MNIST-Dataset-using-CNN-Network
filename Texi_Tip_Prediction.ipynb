# %% [markdown]
# <a href="https://colab.research.google.com/github/mohitrajendramahajan/Taxi_Trip_Tip_Prediction/blob/main/Texi_Tip_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
import pandas as pd

data = pd.read_csv('/content/Distilled_2023_Yellow_Taxi_Trip_Data.txt')
data = pd.DataFrame(data)
display(data.head())
# Out:
#    VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  passenger_count  \
# 0         1  07/29/2023 09:36:48 AM  07/29/2023 09:38:56 AM              2.0
# 1         1  01/10/2023 10:13:12 AM  01/10/2023 10:27:46 AM              0.0
# 2         1  05/11/2023 02:07:59 PM  05/11/2023 02:21:58 PM              1.0
# 3         2  05/10/2023 12:42:14 PM  05/10/2023 12:57:27 PM              1.0
# 4         2  01/03/2023 09:37:59 AM  01/03/2023 09:45:31 AM              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.60         1.0                  N          48.0         142.0
# 1           1.90         1.0                  N         234.0         211.0
# 2           1.70         1.0                  N          68.0         161.0
# 3           1.34         1.0                  N         163.0         237.0
# 4           1.22         1.0                  N         234.0         211.0
#
# ...

# %%
columns_with_single_null = [
    'trip_distance',
    'PULocationID',
    'DOLocationID',
    'payment_type',
    'fare_amount',
    'extra',
    'mta_tax',
    'tip_amount',
    'tolls_amount',
    'improvement_surcharge',
    'total_amount'
]

data.dropna(subset=columns_with_single_null, inplace=True)

print("Null values after dropping rows with single nulls in specified columns:")
display(data.isnull().sum())
# Out:
# Null values after dropping rows with single nulls in specified columns:
# VendorID                     0
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count          19393
# trip_distance                0
# RatecodeID               19393
# store_and_fwd_flag       19393
# PULocationID                 0
# DOLocationID                 0
# payment_type                 0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# improvement_surcharge        0
# total_amount                 0
# congestion_surcharge     19393
# airport_fee              19393
# dtype: int64
